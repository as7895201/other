# %%
import os,re
i=1
path='/home/z/桌面/images/right turn ahead/'
for item in os.listdir(path):        
        print (item)
        i=str(i)
        newname = 'right'+i+'.jpg'
        os.rename(os.path.join(path, item), os.path.join(path,newname))
        print ("转换成" + newname)
        i=int(i)
        i+=1
# Out:
# FireShot Capture 228 - 腾讯地图_ - http___map.qq.com_#pano=1001100312.jpg
# 转换成right1.jpg
# FireShot Capture 207 - 腾讯地图_ - http___map.qq.com_.jpg
# 转换成right2.jpg
# 7181356360.jpg
# 转换成right3.jpg
# FireShot Capture 009 - 腾讯地图_ - http___map.qq.com_#pano=1001101212.jpg
# 转换成right4.jpg
# FireShot Capture 214 - 腾讯地图_ - http___map.qq.com_#pano=1001100312.jpg
# 转换成right5.jpg
# FireShot Capture 042 - 腾讯地图_ - http___map.qq.com_#pano=1001104915.jpg
# 转换成right6.jpg
# FireShot Capture 172 - 腾讯地图_ - http___map.qq.com_.jpg
# 转换成right7.jpg
# FireShot Capture 030 - 腾讯地图_ - http___map.qq.com_#pano=1001102915.jpg
# 转换成right8.jpg
# FireShot Capture 254 - 腾讯地图_ - http___map.qq.com_#pano=1001104915.jpg
# 转换成right9.jpg
# FireShot Capture 261 - 腾讯地图_ - http___map.qq.com_#pano=1001104915.jpg
# 转换成right10.jpg
# FireShot Capture 239 - 腾讯地图_ - http___map.qq.com_#pano=1001100312.jpg
# 转换成right11.jpg
# F200709011628501254511486.jpg
# 转换成right12.jpg
# ...
